# %% [markdown]
# <a href="https://colab.research.google.com/github/sayma-code/Computer-Vision/blob/main/Exercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt
img_bgr = cv2.imread('example.png', cv2.IMREAD_COLOR)
# cv2.imread loads the file example.png from disk as a NumPy array.
# cv2.IMREAD_COLOR tells OpenCV to read a color image with 3 channels in BGR order (Blue, Green, Red).
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis("off")
plt.show()

# %%
print(type(img_bgr))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img_bgr.shape)
# Out:
# (32, 32, 3)

# %% [markdown]
# The last dimension being size 3 indicates there are 3 color channels per pixel

# %%
print(img_bgr[17,8])
# Out:
# [0 3 6]

# %%
img_rgb[10,16] = [255,255,255]
plt.imshow(img_rgb)
plt.axis("off")
plt.show()

# %% [markdown]
# 32 * 32 * 3 = 3072 , 3 kilobytes

# %%
img_rgb_dark = img_rgb // 2
plt.imshow(img_rgb_dark)
plt.axis("off")
plt.show()

# %%
import numpy as np
img_rot = np.zeros(shape=(32, 32, 3), dtype=np.uint8)

H, W, C = img_bgr.shape
for i in range(H):
  for j in range(W):
    img_rot[j, W - 1 - i, :] = img_bgr[i, j, :]
import matplotlib.pyplot as plt
img_rot_rgb = cv2.cvtColor(img_rot, cv2.COLOR_BGR2RGB)
plt.imshow(img_rot_rgb)
plt.axis("off")
plt.show()
