# %% [markdown]
# <a href="https://colab.research.google.com/github/sayma-code/Computer-Vision/blob/main/Excercise4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(4)
# Out:
# 4
